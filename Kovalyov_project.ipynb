# %% [markdown]
# ### Проект “Scraps and losses report”

# %% [markdown]
# Вопрос: компания-производитель продуктов питания осуществляет продажу товаров в торговые объекты. В процессе возникает ситуация, когда торговые объекты возвращают обратно продукт компании (например, у продукта закончился срок годности, брак и т.п.). Это отражается на net sales со знаком минус
#
# Цель: контроль и анализ уровня возвратов, оптимизация уровня возвратов
#
# Задачи: подготовка отчета с таблицами и графиками об уровне возвратов
#
# Инструменты: pandas, postgres, power bi

# %% [markdown]
# #### Этапы:
#
# Сбор исходных данных
# Преобразование данных, построение таблиц
# Создание базы данных
# Обновление данных в БД
# Создание dashboard в Power BI

# %% [markdown]
# #### Исходные данные:
#
# Данные по продажам (sales)
# Данные по возвратам (returns)
# Данные по SKU
# Данные по клиентам (customers)

# %% [markdown]
# #### Преобразование данных:
#
# Работа в Jupyter Notebook с использованием библиотеки Pandas. Применение агрегирующих функций
# Подготовка dataframes и сsv файлов для загрузки в БД
# Создание сводных таблиц в разрезе brand, sub brand, clients и sales people name

# %%
import pandas as pd
import numpy as np
import os
import datetime

# %%
lst = [os.path.join('export_returns', i) for i in os.listdir('export_returns')]
lst1 = sorted(lst, key = os.path.getmtime, reverse=True)
lst1_ = list(item for item in lst1 if "/." not in item)
lst1_
# Out:
# ['export_returns/export_Jan_2023.xlsx',
#  'export_returns/export_Oct_2023.xlsx',
#  'export_returns/export_Sep_2023.xlsx',
#  'export_returns/export_Aug_2023.xlsx',
#  'export_returns/export_Jul_2023.xlsx',
#  'export_returns/export_Jun_2023.xlsx',
#  'export_returns/export_May_2023.xlsx',
#  'export_returns/export_Apr_2023.xlsx',
#  'export_returns/export_Mar_2023.xlsx',
#  'export_returns/export_Feb_2023.xlsx']

# %%
a = lst1_[1]
a
# Out:
# 'export_returns/export_Oct_2023.xlsx'

# %%
df_r = pd.read_excel(a)

#df_r.info()

# %%
df_r = df_r.rename(columns=lambda c: c.lower().replace('.', '_').replace(' ', '_'))

# %%
df_r_1 = df_r.loc[((df_r['sales_document_type'] == 'ZREV') \
                & (df_r['order_reason'] == 'ZU2') \
                & (df_r['reason_for_rejection'].isna()) \
                & (df_r['delivery_block'].isna()) \
                & (df_r['usage'] == 165))].reset_index(drop=True)

df_r_1['week_no'] = df_r_1['requested_deliv_date'].dt.isocalendar().week

df_r_1 = df_r_1.groupby(["ship_to", "material", "week_no"])\
                .agg({"order_quantity": "sum", "order_caf": "sum"})\
                .reset_index()

df_r_2 = df_r[df_r['sales_document_type'].isin(['ZRB'])\
            & df_r['order_reason'].isin(['ZUR'])\
            & df_r['reason_for_rejection'].isnull()\
            & df_r['delivery_block'].isnull()\
            & df_r['usage'].isin([165])].reset_index(drop=True)

df_r_2['week_no'] = df_r_2['requested_deliv_date'].dt.isocalendar().week

df_r_2 = df_r_2.groupby(['ship_to', 'material', 'week_no'])[['order_quantity', 'order_caf']].sum().reset_index()

df_r_3 = df_r.query("sales_document_type == 'ZRB' and order_reason == 'ZUR'\
                        and reason_for_rejection == 'B6' and delivery_block == 'Z3'\
                        and usage == 165").reset_index(drop=True)

df_r_3['week_no'] = df_r_3['requested_deliv_date'].dt.isocalendar().week

df_r_3 = df_r_3.groupby(['ship_to', 'material', 'week_no'])[['order_quantity', 'order_caf']].apply(np.sum, axis=0).reset_index()

# %%
df_r_123 = pd.concat([df_r_1, df_r_2, df_r_3], axis=0).reset_index(drop=True)

df_r_123['order_caf'] = df_r_123['order_caf'] * (-1)

df_returns = pd.pivot_table(df_r_123,
                            index = ['ship_to', 'material', 'week_no'],
                            values = ['order_quantity', 'order_caf'],
                            aggfunc = 'sum').reset_index()

df_returns = df_returns[['ship_to', 'material', 'week_no', 'order_quantity', 'order_caf']]

df_returns.rename(columns = {'order_quantity' : 'scraps_quantity', 'order_caf' : 'scraps_byn'}, inplace=True)

df_returns = df_returns.astype({'ship_to': 'int64', 'material' : 'int64', 'scraps_quantity' : 'int64'})

#df_returns.info()

# %%
df_returns_db = df_returns.copy()

df_returns_db['month'] = df_r.loc[1, 'requested_deliv_date'].month_name()

df_returns_db['year'] = df_r.loc[1, 'requested_deliv_date'].year

# %%
mn = df_r.loc[1, 'requested_deliv_date'].month_name()
mn

y = df_r.loc[1, 'requested_deliv_date'].year
y

period = f"{mn} {y}"
period
# Out:
# 'October 2023'

# %%
first = df_r['requested_deliv_date'].min()
fd = first.strftime('%d.%m.%Y')
fd

second = df_r['requested_deliv_date'].max()
sd = second.strftime('%d.%m.%Y')
sd

dd = f"{fd}-{sd}"
dd
# Out:
# '01.10.2023-31.10.2023'

# %%
file_name_returns = 'returns_database/returns {}.csv'
file_name_returns = file_name_returns.format(dd)

#df_returns_db.to_csv(file_name_returns, index=False)
#print('File {} is created'.format(file_name_returns))

# %% [markdown]
# --

# %%
lstlst = [os.path.join('export_sales', i) for i in os.listdir('export_sales')]
lst2 = sorted(lstlst, key = os.path.getmtime, reverse=True)
lst2_ = list(item for item in lst2 if "/." not in item)
lst2_
# Out:
# ['export_sales/export_Oct_2023.xlsx',
#  'export_sales/export_Sep_2023.xlsx',
#  'export_sales/export_Aug_2023.xlsx',
#  'export_sales/export_Jul_2023.xlsx',
#  'export_sales/export_Jun_2023.xlsx',
#  'export_sales/export_May_2023.xlsx',
#  'export_sales/export_Apr_2023.xlsx',
#  'export_sales/export_Mar_2023.xlsx',
#  'export_sales/export_Feb_2023.xlsx',
#  'export_sales/export_Jan_2023.xlsx']

# %%
b = lst2_[0]
b
# Out:
# 'export_sales/export_Oct_2023.xlsx'

# %%
df_sales = pd.read_excel(b)

# %%
df_sales.rename(columns = {'new Код ТТ' : 'ship_to', 'SAP code NEW' : 'material', 'Неделя' : 'week_no',\
                       'Отгружено шт' : 'sales_quantity', 'Отгружено CAF без НДС' : 'sales_byn'}, inplace=True)

# %%
lambda_fun = lambda x: x[-2 :]

df_sales['week_no'] = df_sales.loc[:, 'week_no'].apply(lambda_fun)

df_sales = df_sales.astype({'week_no' : 'UInt32'})

#df_sales.info()

# %%
df_sales_db = df_sales.copy()

df_sales_db['month'] = df_r.loc[1, 'requested_deliv_date'].month_name()

df_sales_db['year'] = df_r.loc[1, 'requested_deliv_date'].year

# %%
file_name_sales = 'sales_database/sales {}.csv'
file_name_sales = file_name_sales.format(dd)

#df_sales_db.to_csv(file_name_sales, index=False)
#print('File {} is created'.format(file_name_sales))

# %% [markdown]
# --

# %%
df_sales_returns = pd.merge(df_sales, df_returns, how = 'outer', on = ['ship_to', 'material', 'week_no'])

df_sales_returns = df_sales_returns.drop(columns = ['week_no'])

df_sales_returns = df_sales_returns.groupby(['ship_to', 'material']).sum().reset_index()

df_sales_returns = df_sales_returns.astype({'sales_quantity' : 'int64', 'scraps_quantity' : 'int64'})

#df_sales_returns.info()

# %% [markdown]
# --

# %%
df_sku = pd.read_excel('sku/sku.xlsx')

# %%
df_sku = df_sku.rename(columns=lambda c: c.lower().replace('.', '_').replace(' ', '_'))

#df_sku.info()

# %%
df_sku.rename(columns = {'product_id' : 'material', 'subbrand' : 'sub_brand', 'product_desc' : 'sku_name'}, inplace=True)

df_sku = df_sku.astype({'material' : 'int64'})

#df_sku.info()

# %%
#df_sku.to_csv('sku/sku.csv', index=False)

# %% [markdown]
# --

# %%
df_customers = pd.read_excel('customers/customers.xlsx')

#df_customers.info()

# %%
df_customers.rename(columns = {'(CUS) Ship To Code' : 'ship_to', '(CUS-DC) Proxi Category 2' : 'client',\
                               '(CUS-DC) Proxi Category 1' : 'cluster',\
                                '(CUS-SF4) Sales Representative' : 'sales_people_name',\
                                '(CUS-DC) Territory Level 2' : 'region'}, inplace=True)

#df_customers.info()

# %%
#df_customers.to_csv('customers/customers.csv', index=False)

# %% [markdown]
# --

# %%
df_sr_sku = pd.merge(df_sales_returns, df_sku, how = 'left', on = ['material'])

# %%
list_sku_nan = list(df_sr_sku['material'][df_sr_sku['sku_name'].isnull()].value_counts())
list_sku_nan
# Out:
# []

# %%
if not list_sku_nan:
    print('there is all information about the sku')
else:
    raise UserWarning('UPDATE LIST OF SKU')
# Out:
# there is all information about the sku

# %%
df_brands = pd.pivot_table(df_sr_sku, index = ['brand'],
                        values = ['sales_quantity', 'sales_byn', 'scraps_quantity', 'scraps_byn'],
                        aggfunc = 'sum', margins=True)

# %%
df_brands = df_brands.astype({'sales_byn': 'int64', 'scraps_byn' : 'int64'})

df_brands['%_scraps_byn'] = df_brands['scraps_byn'] / df_brands['sales_byn']

df_brands['%_scraps_quantity'] = df_brands['scraps_quantity'] / df_brands['sales_quantity']

# %%
def color_(value):

  if 0 <= value < 0.03:
    color = 'black'
  elif 0.03 <= value <= 1:
    color = 'red'
  else:
    color = 'grey'

  return 'color: %s' % color

# %%
def highlight_last(x):
    
    return ['font-weight: bold' if v == x.iloc[-1] else '' for v in x]

# %%
df_brands_ = df_brands.style.map(color_, subset=['%_scraps_byn','%_scraps_quantity']).\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    apply(highlight_last).\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by brands")

# %%
df_brands_
# Out:
# <style type="text/css">
# #T_30ea2_row0_col0, #T_30ea2_row0_col2, #T_30ea2_row1_col0, #T_30ea2_row1_col2, #T_30ea2_row2_col0, #T_30ea2_row2_col2, #T_30ea2_row3_col0, #T_30ea2_row3_col2, #T_30ea2_row4_col0, #T_30ea2_row4_col2, #T_30ea2_row5_col0, #T_30ea2_row5_col2, #T_30ea2_row6_col0, #T_30ea2_row6_col2, #T_30ea2_row7_col0, #T_30ea2_row7_col2, #T_30ea2_row8_col0, #T_30ea2_row8_col2, #T_30ea2_row9_col0, #T_30ea2_row9_col2 {
#   width: 150px;
# }
# #T_30ea2_row0_col4 {
#   color: red;
#   width: 150px;
# }
# #T_30ea2_row0_col5 {
#   color: red;
# }
# #T_30ea2_row1_col4, #T_30ea2_row3_col4, #T_30ea2_row5_col4, #T_30ea2_row7_col4, #T_30ea2_row8_col4, #T_30ea2_row9_col4 {
#   color: black;
#   width: 150px;
# }
# #T_30ea2_row1_col5, #T_30ea2_row3_col5, #T_30ea2_row5_col5, #T_30ea2_row7_col5, #T_30ea2_row8_col5, #T_30ea2_row9_col5 {
#   color: black;
# }
# #T_30ea2_row2_col4, #T_30ea2_row4_col4, #T_30ea2_row6_col4 {
#   color: grey;
#   width: 150px;
# }
# #T_30ea2_row2_col5, #T_30ea2_row4_col5, #T_30ea2_row6_col5 {
#   color: grey;
# }
# #T_30ea2_row10_col0, #T_30ea2_row10_col2 {
#   font-weight: bold;
#   width: 150px;
# }
# #T_30ea2_row10_col1, #T_30ea2_row10_col3 {
#   font-weight: bold;
# }
# #T_30ea2_row10_col4 {
#   color: black;
#   font-weight: bold;
#   width: 150px;
# }
# #T_30ea2_row10_col5 {
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_30ea2">
#   <caption>Scraps and losses in October 2023 by brands</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30ea2_level0_col0" class="col_heading level0 col0" >sales_byn</th>
#       <th id="T_30ea2_level0_col1" class="col_heading level0 col1" >sales_quantity</th>
#       <th id="T_30ea2_level0_col2" class="col_heading level0 col2" >scraps_byn</th>
#       <th id="T_30ea2_level0_col3" class="col_heading level0 col3" >scraps_quantity</th>
#       <th id="T_30ea2_level0_col4" class="col_heading level0 col4" >%_scraps_byn</th>
#       <th id="T_30ea2_level0_col5" class="col_heading level0 col5" >%_scraps_quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >brand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30ea2_level0_row0" class="row_heading level0 row0" >AB</th>
#       <td id="T_30ea2_row0_col0" class="data row0 col0" >17 428 496</td>
#       <td id="T_30ea2_row0_col1" class="data row0 col1" >13 246 480</td>
#       <td id="T_30ea2_row0_col2" class="data row0 col2" >613 349</td>
#       <td id="T_30ea2_row0_col3" class="data row0 col3" >457 300</td>
#       <td id="T_30ea2_row0_col4" class="data row0 col4" >3,5%</td>
#       <td id="T_30ea2_row0_col5" class="data row0 col5" >3,5%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row1" class="row_heading level0 row1" >ACM</th>
#       <td id="T_30ea2_row1_col0" class="data row1 col0" >6 104 944</td>
#       <td id="T_30ea2_row1_col1" class="data row1 col1" >5 833 240</td>
#       <td id="T_30ea2_row1_col2" class="data row1 col2" >179</td>
#       <td id="T_30ea2_row1_col3" class="data row1 col3" >160</td>
#       <td id="T_30ea2_row1_col4" class="data row1 col4" >0,0%</td>
#       <td id="T_30ea2_row1_col5" class="data row1 col5" >0,0%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row2" class="row_heading level0 row2" >AM</th>
#       <td id="T_30ea2_row2_col0" class="data row2 col0" >22 232</td>
#       <td id="T_30ea2_row2_col1" class="data row2 col1" >15 870</td>
#       <td id="T_30ea2_row2_col2" class="data row2 col2" >135 212</td>
#       <td id="T_30ea2_row2_col3" class="data row2 col3" >120 660</td>
#       <td id="T_30ea2_row2_col4" class="data row2 col4" >608,2%</td>
#       <td id="T_30ea2_row2_col5" class="data row2 col5" >760,3%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row3" class="row_heading level0 row3" >AP</th>
#       <td id="T_30ea2_row3_col0" class="data row3 col0" >2 468 539</td>
#       <td id="T_30ea2_row3_col1" class="data row3 col1" >711 150</td>
#       <td id="T_30ea2_row3_col2" class="data row3 col2" >4 703</td>
#       <td id="T_30ea2_row3_col3" class="data row3 col3" >1 340</td>
#       <td id="T_30ea2_row3_col4" class="data row3 col4" >0,2%</td>
#       <td id="T_30ea2_row3_col5" class="data row3 col5" >0,2%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row4" class="row_heading level0 row4" >AV</th>
#       <td id="T_30ea2_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_30ea2_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_30ea2_row4_col2" class="data row4 col2" >15 558</td>
#       <td id="T_30ea2_row4_col3" class="data row4 col3" >12 220</td>
#       <td id="T_30ea2_row4_col4" class="data row4 col4" >111128,6%</td>
#       <td id="T_30ea2_row4_col5" class="data row4 col5" >61100,0%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row5" class="row_heading level0 row5" >DM</th>
#       <td id="T_30ea2_row5_col0" class="data row5 col0" >8 411 722</td>
#       <td id="T_30ea2_row5_col1" class="data row5 col1" >8 093 610</td>
#       <td id="T_30ea2_row5_col2" class="data row5 col2" >68 817</td>
#       <td id="T_30ea2_row5_col3" class="data row5 col3" >60 340</td>
#       <td id="T_30ea2_row5_col4" class="data row5 col4" >0,8%</td>
#       <td id="T_30ea2_row5_col5" class="data row5 col5" >0,7%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row6" class="row_heading level0 row6" >DN</th>
#       <td id="T_30ea2_row6_col0" class="data row6 col0" >15</td>
#       <td id="T_30ea2_row6_col1" class="data row6 col1" >30</td>
#       <td id="T_30ea2_row6_col2" class="data row6 col2" >653</td>
#       <td id="T_30ea2_row6_col3" class="data row6 col3" >1 210</td>
#       <td id="T_30ea2_row6_col4" class="data row6 col4" >4353,3%</td>
#       <td id="T_30ea2_row6_col5" class="data row6 col5" >4033,3%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row7" class="row_heading level0 row7" >PR</th>
#       <td id="T_30ea2_row7_col0" class="data row7 col0" >9 885 873</td>
#       <td id="T_30ea2_row7_col1" class="data row7 col1" >6 904 410</td>
#       <td id="T_30ea2_row7_col2" class="data row7 col2" >205 741</td>
#       <td id="T_30ea2_row7_col3" class="data row7 col3" >114 350</td>
#       <td id="T_30ea2_row7_col4" class="data row7 col4" >2,1%</td>
#       <td id="T_30ea2_row7_col5" class="data row7 col5" >1,7%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row8" class="row_heading level0 row8" >PT</th>
#       <td id="T_30ea2_row8_col0" class="data row8 col0" >3 474 421</td>
#       <td id="T_30ea2_row8_col1" class="data row8 col1" >403 110</td>
#       <td id="T_30ea2_row8_col2" class="data row8 col2" >23 677</td>
#       <td id="T_30ea2_row8_col3" class="data row8 col3" >2 710</td>
#       <td id="T_30ea2_row8_col4" class="data row8 col4" >0,7%</td>
#       <td id="T_30ea2_row8_col5" class="data row8 col5" >0,7%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row9" class="row_heading level0 row9" >RS</th>
#       <td id="T_30ea2_row9_col0" class="data row9 col0" >8 355 806</td>
#       <td id="T_30ea2_row9_col1" class="data row9 col1" >7 649 900</td>
#       <td id="T_30ea2_row9_col2" class="data row9 col2" >119 748</td>
#       <td id="T_30ea2_row9_col3" class="data row9 col3" >75 950</td>
#       <td id="T_30ea2_row9_col4" class="data row9 col4" >1,4%</td>
#       <td id="T_30ea2_row9_col5" class="data row9 col5" >1,0%</td>
#     </tr>
#     <tr>
#       <th id="T_30ea2_level0_row10" class="row_heading level0 row10" >All</th>
#       <td id="T_30ea2_row10_col0" class="data row10 col0" >56 152 067</td>
#       <td id="T_30ea2_row10_col1" class="data row10 col1" >42 857 820</td>
#       <td id="T_30ea2_row10_col2" class="data row10 col2" >1 187 640</td>
#       <td id="T_30ea2_row10_col3" class="data row10 col3" >846 240</td>
#       <td id="T_30ea2_row10_col4" class="data row10 col4" >2,1%</td>
#       <td id="T_30ea2_row10_col5" class="data row10 col5" >2,0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Уровни возвратов выше 100% у таких брендов, как AV, AM и DN обусловлены тем, что данные бренды выведены из продажи и сейчас происходит списание. Это нормально, однако вывод бренда DN был осуществлен еще весной 2023, поэтому необходимо выяснить, почему до сих пор есть возвраты. Вывод бренда AV был в июле 2023, поэтому данный уровень списания (в абсолютных значениях) в принципе нормален. Вывод бренда AM осуществлен (осуществляется) в октябре 2023, поэтому высокие абсолютные значения возвратов тоже нормальны.
#
# Бренд AB пришел на замену бренда AV. Высокий уровень возвратов может говорить о том, что фактический спрос оказался ниже прогнозируемого. А также стоит проверить, понимают ли торговые представители, что заказывать стоит меньше.
#
# Бренд ACM пришел на замену бренда AM. Продажи только начались, возвраты еще не проводились.

# %% [markdown]
# ---

# %%
df_sub_brands = pd.pivot_table(df_sr_sku, index = ['sub_brand'],
                        values = ['sales_quantity', 'sales_byn', 'scraps_quantity', 'scraps_byn'],
                        aggfunc = 'sum', margins=True)

df_sub_brands['%_scraps_byn'] = df_sub_brands['scraps_byn'] / df_sub_brands['sales_byn']

df_sub_brands['%_scraps_quantity'] = df_sub_brands['scraps_quantity'] / df_sub_brands['sales_quantity']

df_sub_brands = df_sub_brands.astype({'sales_byn': 'int64', 'scraps_byn' : 'int64'})

df_sub_brands = df_sub_brands.dropna()

#df_sub_brands

# %%
df_sub_brands.style.\
    map(color_, subset=['%_scraps_byn','%_scraps_quantity']).\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    apply(highlight_last).\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by sub brands")
# Out:
# <style type="text/css">
# #T_0cf5b_row0_col0, #T_0cf5b_row0_col2, #T_0cf5b_row1_col0, #T_0cf5b_row1_col2, #T_0cf5b_row2_col0, #T_0cf5b_row2_col2, #T_0cf5b_row3_col0, #T_0cf5b_row3_col2, #T_0cf5b_row4_col0, #T_0cf5b_row4_col2, #T_0cf5b_row5_col0, #T_0cf5b_row5_col2, #T_0cf5b_row6_col0, #T_0cf5b_row6_col2, #T_0cf5b_row7_col0, #T_0cf5b_row7_col2, #T_0cf5b_row8_col0, #T_0cf5b_row8_col2, #T_0cf5b_row9_col0, #T_0cf5b_row9_col2, #T_0cf5b_row10_col0, #T_0cf5b_row10_col2, #T_0cf5b_row11_col0, #T_0cf5b_row11_col2, #T_0cf5b_row12_col0, #T_0cf5b_row12_col2, #T_0cf5b_row13_col0, #T_0cf5b_row13_col2, #T_0cf5b_row14_col0, #T_0cf5b_row14_col2, #T_0cf5b_row15_col0, #T_0cf5b_row15_col2, #T_0cf5b_row16_col0, #T_0cf5b_row16_col2, #T_0cf5b_row17_col0, #T_0cf5b_row17_col2, #T_0cf5b_row18_col0, #T_0cf5b_row18_col2, #T_0cf5b_row19_col0, #T_0cf5b_row19_col2, #T_0cf5b_row20_col0, #T_0cf5b_row20_col2, #T_0cf5b_row21_col0, #T_0cf5b_row21_col2, #T_0cf5b_row22_col0, #T_0cf5b_row22_col2, #T_0cf5b_row23_col0, #T_0cf5b_row23_col2, #T_0cf5b_row24_col0, #T_0cf5b_row24_col2, #T_0cf5b_row25_col0, #T_0cf5b_row25_col2, #T_0cf5b_row26_col0, #T_0cf5b_row26_col2, #T_0cf5b_row27_col0, #T_0cf5b_row27_col2, #T_0cf5b_row28_col0, #T_0cf5b_row28_col2, #T_0cf5b_row29_col0, #T_0cf5b_row29_col2, #T_0cf5b_row30_col0, #T_0cf5b_row30_col2, #T_0cf5b_row31_col0, #T_0cf5b_row31_col2, #T_0cf5b_row32_col0, #T_0cf5b_row32_col2, #T_0cf5b_row33_col0, #T_0cf5b_row33_col2, #T_0cf5b_row34_col0, #T_0cf5b_row34_col2, #T_0cf5b_row35_col0, #T_0cf5b_row35_col2, #T_0cf5b_row36_col0, #T_0cf5b_row36_col2, #T_0cf5b_row37_col0, #T_0cf5b_row37_col2, #T_0cf5b_row38_col0, #T_0cf5b_row38_col2, #T_0cf5b_row39_col0, #T_0cf5b_row39_col2, #T_0cf5b_row40_col0, #T_0cf5b_row40_col2, #T_0cf5b_row41_col0, #T_0cf5b_row41_col2, #T_0cf5b_row42_col0, #T_0cf5b_row42_col2, #T_0cf5b_row43_col0, #T_0cf5b_row43_col2, #T_0cf5b_row44_col0, #T_0cf5b_row44_col2 {
#   width: 150px;
# }
# #T_0cf5b_row0_col4, #T_0cf5b_row2_col4, #T_0cf5b_row4_col4, #T_0cf5b_row5_col4, #T_0cf5b_row35_col4, #T_0cf5b_row43_col4 {
#   color: red;
#   width: 150px;
# }
# #T_0cf5b_row0_col5, #T_0cf5b_row2_col5, #T_0cf5b_row4_col5, #T_0cf5b_row5_col5, #T_0cf5b_row35_col5 {
#   color: red;
# }
# #T_0cf5b_row1_col4, #T_0cf5b_row3_col4, #T_0cf5b_row6_col4, #T_0cf5b_row7_col4, #T_0cf5b_row10_col4, #T_0cf5b_row12_col4, #T_0cf5b_row13_col4, #T_0cf5b_row14_col4, #T_0cf5b_row15_col4, #T_0cf5b_row16_col4, #T_0cf5b_row17_col4, #T_0cf5b_row24_col4, #T_0cf5b_row25_col4, #T_0cf5b_row26_col4, #T_0cf5b_row27_col4, #T_0cf5b_row29_col4, #T_0cf5b_row30_col4, #T_0cf5b_row31_col4, #T_0cf5b_row32_col4, #T_0cf5b_row33_col4, #T_0cf5b_row36_col4, #T_0cf5b_row37_col4, #T_0cf5b_row38_col4, #T_0cf5b_row39_col4, #T_0cf5b_row40_col4, #T_0cf5b_row41_col4, #T_0cf5b_row42_col4, #T_0cf5b_row44_col4 {
#   color: black;
#   width: 150px;
# }
# #T_0cf5b_row1_col5, #T_0cf5b_row3_col5, #T_0cf5b_row6_col5, #T_0cf5b_row7_col5, #T_0cf5b_row10_col5, #T_0cf5b_row12_col5, #T_0cf5b_row13_col5, #T_0cf5b_row14_col5, #T_0cf5b_row15_col5, #T_0cf5b_row16_col5, #T_0cf5b_row17_col5, #T_0cf5b_row24_col5, #T_0cf5b_row25_col5, #T_0cf5b_row26_col5, #T_0cf5b_row27_col5, #T_0cf5b_row29_col5, #T_0cf5b_row30_col5, #T_0cf5b_row31_col5, #T_0cf5b_row32_col5, #T_0cf5b_row33_col5, #T_0cf5b_row36_col5, #T_0cf5b_row37_col5, #T_0cf5b_row38_col5, #T_0cf5b_row39_col5, #T_0cf5b_row40_col5, #T_0cf5b_row41_col5, #T_0cf5b_row42_col5, #T_0cf5b_row43_col5, #T_0cf5b_row44_col5 {
#   color: black;
# }
# #T_0cf5b_row8_col4, #T_0cf5b_row9_col4, #T_0cf5b_row11_col4, #T_0cf5b_row18_col4, #T_0cf5b_row19_col4, #T_0cf5b_row20_col4, #T_0cf5b_row21_col4, #T_0cf5b_row22_col4, #T_0cf5b_row23_col4, #T_0cf5b_row28_col4, #T_0cf5b_row34_col4 {
#   color: grey;
#   width: 150px;
# }
# #T_0cf5b_row8_col5, #T_0cf5b_row9_col5, #T_0cf5b_row11_col5, #T_0cf5b_row18_col5, #T_0cf5b_row19_col5, #T_0cf5b_row20_col5, #T_0cf5b_row21_col5, #T_0cf5b_row22_col5, #T_0cf5b_row23_col5, #T_0cf5b_row28_col5, #T_0cf5b_row34_col5 {
#   color: grey;
# }
# #T_0cf5b_row45_col0, #T_0cf5b_row45_col2 {
#   font-weight: bold;
#   width: 150px;
# }
# #T_0cf5b_row45_col1, #T_0cf5b_row45_col3 {
#   font-weight: bold;
# }
# #T_0cf5b_row45_col4 {
#   color: black;
#   font-weight: bold;
#   width: 150px;
# }
# #T_0cf5b_row45_col5 {
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_0cf5b">
#   <caption>Scraps and losses in October 2023 by sub brands</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cf5b_level0_col0" class="col_heading level0 col0" >sales_byn</th>
#       <th id="T_0cf5b_level0_col1" class="col_heading level0 col1" >sales_quantity</th>
#       <th id="T_0cf5b_level0_col2" class="col_heading level0 col2" >scraps_byn</th>
#       <th id="T_0cf5b_level0_col3" class="col_heading level0 col3" >scraps_quantity</th>
#       <th id="T_0cf5b_level0_col4" class="col_heading level0 col4" >%_scraps_byn</th>
#       <th id="T_0cf5b_level0_col5" class="col_heading level0 col5" >%_scraps_quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sub_brand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cf5b_level0_row0" class="row_heading level0 row0" >AB 1110</th>
#       <td id="T_0cf5b_row0_col0" class="data row0 col0" >899 390</td>
#       <td id="T_0cf5b_row0_col1" class="data row0 col1" >1 045 810</td>
#       <td id="T_0cf5b_row0_col2" class="data row0 col2" >49 125</td>
#       <td id="T_0cf5b_row0_col3" class="data row0 col3" >58 440</td>
#       <td id="T_0cf5b_row0_col4" class="data row0 col4" >5,5%</td>
#       <td id="T_0cf5b_row0_col5" class="data row0 col5" >5,6%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5b_level0_row1" class="row_heading level0 row1" >AB 130</th>
#       <td id="T_0cf5b_row1_col0" class="data row1 col0" >2 877 274</td>
#       <td id="T_0cf5b_row1_col1" class="data row1 col1" >2 968 640</td>
#       <td id="T_0cf5b_row1_col2" class="data row1 col2" >53 392</td>
#       <td id="T_0cf5b_row1_col3" class="data row1 col3" >55 400</td>
#       <td id="T_0cf5b_row1_col4" class="data row1 col4" >1,9%</td>
#       <td id="T_0cf5b_row1_col5" class="data row1 col5" >1,9%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5b_level0_row2" class="row_heading level0 row2" >AB 130 N</th>
#       <td id="T_0cf5b_row2_col0" class="data row2 col0" >1 653 410</td>
#       <td id="T_0cf5b_row2_col1" class="data row2 col1" >1 483 600</td>
#       <td id="T_0cf5b_row2_col2" class="data row2 col2" >59 165</td>
#       <td id="T_0cf5b_row2_col3" class="data row2 col3" >52 420</td>
#       <td id="T_0cf5b_row2_col4" class="data row2 col4" >3,6%</td>
#       <td id="T_0cf5b_row2_col5" class="data row2 col5" >3,5%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5b_level0_row3" class="row_heading level0 row3" >AB 140</th>
#       <td id="T_0cf5b_row3_col0" class="data row3 col0" >3 132 233</td>
#       <td id="T_0cf5b_row3_col1" class="data row3 col1" >2 519 750</td>
#       <td id="T_0cf5b_row3_col2" class="data row3 col2" >82 455</td>
#       <td id="T_0cf5b_row3_col3" class="data row3 col3" >65 760</td>
#       <td id="T_0cf5b_row3_col4" class="data row3 col4" >2,6%</td>
#       <td id="T_0cf5b_row3_col5" class="data row3 col5" >2,6%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5b_level0_row4" class="row_heading level0 row4" >AB 220</th>
#       <td id="T_0cf5b_row4_col0" class="data row4 col0" >457 737</td>
#       <td id="T_0cf5b_row4_col1" class="data row4 col1" >286 940</td>
#       <td id="T_0cf5b_row4_col2" class="data row4 col2" >17 166</td>
#       <td id="T_0cf5b_row4_col3" class="data row4 col3" >10 820</td>
#       <td id="T_0cf5b_row4_col4" class="data row4 col4" >3,8%</td>
#       <td id="T_0cf5b_row4_col5" class="data row4 col5" >3,8%</td>
#     </tr>
#     <tr>
#       <th id="T_0cf5b_level0_row5" class="row_heading level0 row5" >AB 260 N</th>
#       <td id="T_0cf5b_row5_col0" class="data row5 col0" >8 408 450</td>

# %%
df_sub_brands_1 = df_sub_brands.copy()

# %%
df_sub_brands_2 = (df_sub_brands_1[(df_sub_brands_1['%_scraps_byn'] > 0.025) & (df_sub_brands_1['%_scraps_byn'] <= 1)]).\
                    sort_values('%_scraps_byn', ascending=False)
#df_sub_brands_2

# %%
df_sub_brands_2.style.\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by sub brands more 2,5%")
# Out:
# <style type="text/css">
# #T_aef82_row0_col0, #T_aef82_row0_col2, #T_aef82_row0_col4, #T_aef82_row1_col0, #T_aef82_row1_col2, #T_aef82_row1_col4, #T_aef82_row2_col0, #T_aef82_row2_col2, #T_aef82_row2_col4, #T_aef82_row3_col0, #T_aef82_row3_col2, #T_aef82_row3_col4, #T_aef82_row4_col0, #T_aef82_row4_col2, #T_aef82_row4_col4, #T_aef82_row5_col0, #T_aef82_row5_col2, #T_aef82_row5_col4, #T_aef82_row6_col0, #T_aef82_row6_col2, #T_aef82_row6_col4, #T_aef82_row7_col0, #T_aef82_row7_col2, #T_aef82_row7_col4 {
#   width: 150px;
# }
# </style>
# <table id="T_aef82">
#   <caption>Scraps and losses in October 2023 by sub brands more 2,5%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aef82_level0_col0" class="col_heading level0 col0" >sales_byn</th>
#       <th id="T_aef82_level0_col1" class="col_heading level0 col1" >sales_quantity</th>
#       <th id="T_aef82_level0_col2" class="col_heading level0 col2" >scraps_byn</th>
#       <th id="T_aef82_level0_col3" class="col_heading level0 col3" >scraps_quantity</th>
#       <th id="T_aef82_level0_col4" class="col_heading level0 col4" >%_scraps_byn</th>
#       <th id="T_aef82_level0_col5" class="col_heading level0 col5" >%_scraps_quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sub_brand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aef82_level0_row0" class="row_heading level0 row0" >PR M 900</th>
#       <td id="T_aef82_row0_col0" class="data row0 col0" >1 146 174</td>
#       <td id="T_aef82_row0_col1" class="data row0 col1" >473 710</td>
#       <td id="T_aef82_row0_col2" class="data row0 col2" >106 980</td>
#       <td id="T_aef82_row0_col3" class="data row0 col3" >44 210</td>
#       <td id="T_aef82_row0_col4" class="data row0 col4" >9,3%</td>
#       <td id="T_aef82_row0_col5" class="data row0 col5" >9,3%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row1" class="row_heading level0 row1" >AB 1110</th>
#       <td id="T_aef82_row1_col0" class="data row1 col0" >899 390</td>
#       <td id="T_aef82_row1_col1" class="data row1 col1" >1 045 810</td>
#       <td id="T_aef82_row1_col2" class="data row1 col2" >49 125</td>
#       <td id="T_aef82_row1_col3" class="data row1 col3" >58 440</td>
#       <td id="T_aef82_row1_col4" class="data row1 col4" >5,5%</td>
#       <td id="T_aef82_row1_col5" class="data row1 col5" >5,6%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row2" class="row_heading level0 row2" >AB 260 N</th>
#       <td id="T_aef82_row2_col0" class="data row2 col0" >8 408 450</td>
#       <td id="T_aef82_row2_col1" class="data row2 col1" >4 941 740</td>
#       <td id="T_aef82_row2_col2" class="data row2 col2" >352 043</td>
#       <td id="T_aef82_row2_col3" class="data row2 col3" >214 460</td>
#       <td id="T_aef82_row2_col4" class="data row2 col4" >4,2%</td>
#       <td id="T_aef82_row2_col5" class="data row2 col5" >4,3%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row3" class="row_heading level0 row3" >AB 220</th>
#       <td id="T_aef82_row3_col0" class="data row3 col0" >457 737</td>
#       <td id="T_aef82_row3_col1" class="data row3 col1" >286 940</td>
#       <td id="T_aef82_row3_col2" class="data row3 col2" >17 166</td>
#       <td id="T_aef82_row3_col3" class="data row3 col3" >10 820</td>
#       <td id="T_aef82_row3_col4" class="data row3 col4" >3,8%</td>
#       <td id="T_aef82_row3_col5" class="data row3 col5" >3,8%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row4" class="row_heading level0 row4" >AB 130 N</th>
#       <td id="T_aef82_row4_col0" class="data row4 col0" >1 653 410</td>
#       <td id="T_aef82_row4_col1" class="data row4 col1" >1 483 600</td>
#       <td id="T_aef82_row4_col2" class="data row4 col2" >59 165</td>
#       <td id="T_aef82_row4_col3" class="data row4 col3" >52 420</td>
#       <td id="T_aef82_row4_col4" class="data row4 col4" >3,6%</td>
#       <td id="T_aef82_row4_col5" class="data row4 col5" >3,5%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row5" class="row_heading level0 row5" >RS CR 45</th>
#       <td id="T_aef82_row5_col0" class="data row5 col0" >1 295 931</td>
#       <td id="T_aef82_row5_col1" class="data row5 col1" >915 100</td>
#       <td id="T_aef82_row5_col2" class="data row5 col2" >46 357</td>
#       <td id="T_aef82_row5_col3" class="data row5 col3" >24 050</td>
#       <td id="T_aef82_row5_col4" class="data row5 col4" >3,6%</td>
#       <td id="T_aef82_row5_col5" class="data row5 col5" >2,6%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row6" class="row_heading level0 row6" >RS 90</th>
#       <td id="T_aef82_row6_col0" class="data row6 col0" >1 592 455</td>
#       <td id="T_aef82_row6_col1" class="data row6 col1" >1 097 480</td>
#       <td id="T_aef82_row6_col2" class="data row6 col2" >45 444</td>
#       <td id="T_aef82_row6_col3" class="data row6 col3" >26 200</td>
#       <td id="T_aef82_row6_col4" class="data row6 col4" >2,9%</td>
#       <td id="T_aef82_row6_col5" class="data row6 col5" >2,4%</td>
#     </tr>
#     <tr>
#       <th id="T_aef82_level0_row7" class="row_heading level0 row7" >AB 140</th>
#       <td id="T_aef82_row7_col0" class="data row7 col0" >3 132 233</td>
#       <td id="T_aef82_row7_col1" class="data row7 col1" >2 519 750</td>
#       <td id="T_aef82_row7_col2" class="data row7 col2" >82 455</td>
#       <td id="T_aef82_row7_col3" class="data row7 col3" >65 760</td>
#       <td id="T_aef82_row7_col4" class="data row7 col4" >2,6%</td>
#       <td id="T_aef82_row7_col5" class="data row7 col5" >2,6%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Высокий уровень PR M 900 обусловлен тем, что в конце сентября был осуществлен вывод продукта из продажи.
#
# Высокий уровень у RS CR 45 и RS 90 может быть обусловлен тем, что мы не угадали с влиянием понижения цены на спрос и/или с влиянием изменения изображения на баночках на спрос (продукт детского питания, изображения из известных детских мультиков). Также осенью всегда изменяется уровень сезонности на данный типа продукта. Возможно требуется пересмотреть расчет уровня сезонности.

# %%
df_sr_customers = pd.merge(df_sales_returns, df_customers, how = 'left', on = ['ship_to'])

# %%
list_customers_nan = list(df_sr_customers['ship_to'][df_sr_customers['client'].isnull()].value_counts())
list_customers_nan
# Out:
# []

# %%
if not list_customers_nan:
    print('there is all information about the clients')
else:
    raise UserWarning('UPDATE LIST OF CUSTOMERS')
# Out:
# there is all information about the clients

# %%
#df_sr_customers

# %%
df_clients = pd.pivot_table(df_sr_customers, index = ['client'],
                        values = ['sales_quantity', 'sales_byn', 'scraps_quantity', 'scraps_byn'],
                        aggfunc = 'sum')

df_clients['%_scraps_byn'] = df_clients['scraps_byn'] / df_clients['sales_byn']

df_clients['%_scraps_quantity'] = df_clients['scraps_quantity'] / df_clients['sales_quantity']

df_clients = df_clients.astype({'sales_byn': 'int64', 'scraps_byn' : 'int64'})

#df_clients

# %%
df_clients.style.\
    map(color_, subset=['%_scraps_byn','%_scraps_quantity']).\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by clients")
# Out:
# <style type="text/css">
# #T_93f8c_row0_col0, #T_93f8c_row0_col2, #T_93f8c_row1_col0, #T_93f8c_row1_col2, #T_93f8c_row2_col0, #T_93f8c_row2_col2, #T_93f8c_row3_col0, #T_93f8c_row3_col2, #T_93f8c_row4_col0, #T_93f8c_row4_col2, #T_93f8c_row5_col0, #T_93f8c_row5_col2, #T_93f8c_row6_col0, #T_93f8c_row6_col2, #T_93f8c_row7_col0, #T_93f8c_row7_col2, #T_93f8c_row8_col0, #T_93f8c_row8_col2, #T_93f8c_row9_col0, #T_93f8c_row9_col2, #T_93f8c_row10_col0, #T_93f8c_row10_col2, #T_93f8c_row11_col0, #T_93f8c_row11_col2, #T_93f8c_row12_col0, #T_93f8c_row12_col2, #T_93f8c_row13_col0, #T_93f8c_row13_col2, #T_93f8c_row14_col0, #T_93f8c_row14_col2, #T_93f8c_row15_col0, #T_93f8c_row15_col2, #T_93f8c_row16_col0, #T_93f8c_row16_col2, #T_93f8c_row17_col0, #T_93f8c_row17_col2, #T_93f8c_row18_col0, #T_93f8c_row18_col2, #T_93f8c_row19_col0, #T_93f8c_row19_col2, #T_93f8c_row20_col0, #T_93f8c_row20_col2, #T_93f8c_row21_col0, #T_93f8c_row21_col2 {
#   width: 150px;
# }
# #T_93f8c_row0_col4, #T_93f8c_row2_col4, #T_93f8c_row3_col4, #T_93f8c_row4_col4, #T_93f8c_row5_col4, #T_93f8c_row6_col4, #T_93f8c_row7_col4, #T_93f8c_row9_col4, #T_93f8c_row12_col4, #T_93f8c_row13_col4, #T_93f8c_row14_col4, #T_93f8c_row15_col4, #T_93f8c_row17_col4, #T_93f8c_row18_col4, #T_93f8c_row19_col4, #T_93f8c_row21_col4 {
#   color: black;
#   width: 150px;
# }
# #T_93f8c_row0_col5, #T_93f8c_row2_col5, #T_93f8c_row3_col5, #T_93f8c_row4_col5, #T_93f8c_row5_col5, #T_93f8c_row6_col5, #T_93f8c_row7_col5, #T_93f8c_row8_col5, #T_93f8c_row9_col5, #T_93f8c_row10_col5, #T_93f8c_row12_col5, #T_93f8c_row13_col5, #T_93f8c_row14_col5, #T_93f8c_row15_col5, #T_93f8c_row17_col5, #T_93f8c_row18_col5, #T_93f8c_row19_col5, #T_93f8c_row21_col5 {
#   color: black;
# }
# #T_93f8c_row1_col4, #T_93f8c_row8_col4, #T_93f8c_row10_col4, #T_93f8c_row11_col4, #T_93f8c_row16_col4, #T_93f8c_row20_col4 {
#   color: red;
#   width: 150px;
# }
# #T_93f8c_row1_col5, #T_93f8c_row11_col5, #T_93f8c_row16_col5, #T_93f8c_row20_col5 {
#   color: red;
# }
# </style>
# <table id="T_93f8c">
#   <caption>Scraps and losses in October 2023 by clients</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93f8c_level0_col0" class="col_heading level0 col0" >sales_byn</th>
#       <th id="T_93f8c_level0_col1" class="col_heading level0 col1" >sales_quantity</th>
#       <th id="T_93f8c_level0_col2" class="col_heading level0 col2" >scraps_byn</th>
#       <th id="T_93f8c_level0_col3" class="col_heading level0 col3" >scraps_quantity</th>
#       <th id="T_93f8c_level0_col4" class="col_heading level0 col4" >%_scraps_byn</th>
#       <th id="T_93f8c_level0_col5" class="col_heading level0 col5" >%_scraps_quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >client</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93f8c_level0_row0" class="row_heading level0 row0" >Alm</th>
#       <td id="T_93f8c_row0_col0" class="data row0 col0" >1 642 958</td>
#       <td id="T_93f8c_row0_col1" class="data row0 col1" >1 295 960</td>
#       <td id="T_93f8c_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_93f8c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_93f8c_row0_col4" class="data row0 col4" >0,0%</td>
#       <td id="T_93f8c_row0_col5" class="data row0 col5" >0,0%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row1" class="row_heading level0 row1" >Bel</th>
#       <td id="T_93f8c_row1_col0" class="data row1 col0" >1 648 069</td>
#       <td id="T_93f8c_row1_col1" class="data row1 col1" >1 215 170</td>
#       <td id="T_93f8c_row1_col2" class="data row1 col2" >58 703</td>
#       <td id="T_93f8c_row1_col3" class="data row1 col3" >42 960</td>
#       <td id="T_93f8c_row1_col4" class="data row1 col4" >3,6%</td>
#       <td id="T_93f8c_row1_col5" class="data row1 col5" >3,5%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row2" class="row_heading level0 row2" >Dob</th>
#       <td id="T_93f8c_row2_col0" class="data row2 col0" >3 692 153</td>
#       <td id="T_93f8c_row2_col1" class="data row2 col1" >3 238 930</td>
#       <td id="T_93f8c_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_93f8c_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_93f8c_row2_col4" class="data row2 col4" >0,0%</td>
#       <td id="T_93f8c_row2_col5" class="data row2 col5" >0,0%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row3" class="row_heading level0 row3" >E-d</th>
#       <td id="T_93f8c_row3_col0" class="data row3 col0" >946 720</td>
#       <td id="T_93f8c_row3_col1" class="data row3 col1" >588 130</td>
#       <td id="T_93f8c_row3_col2" class="data row3 col2" >7 464</td>
#       <td id="T_93f8c_row3_col3" class="data row3 col3" >5 690</td>
#       <td id="T_93f8c_row3_col4" class="data row3 col4" >0,8%</td>
#       <td id="T_93f8c_row3_col5" class="data row3 col5" >1,0%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row4" class="row_heading level0 row4" >Eur</th>
#       <td id="T_93f8c_row4_col0" class="data row4 col0" >10 074 055</td>
#       <td id="T_93f8c_row4_col1" class="data row4 col1" >8 222 860</td>
#       <td id="T_93f8c_row4_col2" class="data row4 col2" >296 022</td>
#       <td id="T_93f8c_row4_col3" class="data row4 col3" >207 720</td>
#       <td id="T_93f8c_row4_col4" class="data row4 col4" >2,9%</td>
#       <td id="T_93f8c_row4_col5" class="data row4 col5" >2,5%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row5" class="row_heading level0 row5" >GRI</th>
#       <td id="T_93f8c_row5_col0" class="data row5 col0" >3 388 713</td>
#       <td id="T_93f8c_row5_col1" class="data row5 col1" >2 459 530</td>
#       <td id="T_93f8c_row5_col2" class="data row5 col2" >42 861</td>
#       <td id="T_93f8c_row5_col3" class="data row5 col3" >33 160</td>
#       <td id="T_93f8c_row5_col4" class="data row5 col4" >1,3%</td>
#       <td id="T_93f8c_row5_col5" class="data row5 col5" >1,3%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row6" class="row_heading level0 row6" >Gro</th>
#       <td id="T_93f8c_row6_col0" class="data row6 col0" >4 172 144</td>
#       <td id="T_93f8c_row6_col1" class="data row6 col1" >4 060 390</td>
#       <td id="T_93f8c_row6_col2" class="data row6 col2" >31 414</td>
#       <td id="T_93f8c_row6_col3" class="data row6 col3" >26 920</td>
#       <td id="T_93f8c_row6_col4" class="data row6 col4" >0,8%</td>
#       <td id="T_93f8c_row6_col5" class="data row6 col5" >0,7%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row7" class="row_heading level0 row7" >Hip</th>
#       <td id="T_93f8c_row7_col0" class="data row7 col0" >3 305 817</td>
#       <td id="T_93f8c_row7_col1" class="data row7 col1" >2 507 620</td>
#       <td id="T_93f8c_row7_col2" class="data row7 col2" >48 642</td>
#       <td id="T_93f8c_row7_col3" class="data row7 col3" >35 500</td>
#       <td id="T_93f8c_row7_col4" class="data row7 col4" >1,5%</td>
#       <td id="T_93f8c_row7_col5" class="data row7 col5" >1,4%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row8" class="row_heading level0 row8" >Hit</th>
#       <td id="T_93f8c_row8_col0" class="data row8 col0" >2 421 246</td>
#       <td id="T_93f8c_row8_col1" class="data row8 col1" >2 300 500</td>
#       <td id="T_93f8c_row8_col2" class="data row8 col2" >85 422</td>
#       <td id="T_93f8c_row8_col3" class="data row8 col3" >57 210</td>
#       <td id="T_93f8c_row8_col4" class="data row8 col4" >3,5%</td>
#       <td id="T_93f8c_row8_col5" class="data row8 col5" >2,5%</td>
#     </tr>
#     <tr>
#       <th id="T_93f8c_level0_row9" class="row_heading level0 row9" >Kor</th>
#       <td id="T_93f8c_row9_col0" class="data row9 col0" >3 659 749</td>
#       <td id="T_93f8c_row9_col1" class="data row9 col1" >2 677 500</td>
#       <td id="T_93f8c_row9_col2" class="data row9 col2" >46 089</td>
#       <td id="T_93f8c_row9_col3" class="data row9 col3" >36 100</td>
#       <td id="T_93f8c_row9_col4" class="data row9 col4" >1,3%

# %% [markdown]
# Высокий уровень возвратов в торговых сетях может быть обусловлен ценовой политикой данных сетей или уровнем ответственности торговых представителей, которые работают в этих сетях.

# %%
df_sales_people_sku = pd.merge(df_sr_customers, df_sku, how='left', on=['material'])

# %%
df_sales_people_sku
# Out:
#           ship_to  material  sales_quantity  sales_byn  scraps_quantity  \
# 0       850232377     48949             480      456.0                0
# 1       850232377     97192             180      158.4                0
# 2       850232377     99639             320      483.2                0
# 3       850232377     99640             400      604.0                0
# 4       850232377    101209             120      169.2               10
# ...           ...       ...             ...        ...              ...
# 106833  850310862    194717              70      119.0                0
# 106834  850310862    194729             130      221.0                0
# 106835  850310862    194858              60       77.4                0
# 106836  850310862    196459              60       67.2                0
# 106837  850310862    196460              60       67.2                0
#
#         scraps_byn    cluster client sales_people_name          region brand  \
# 0              0.0  Cluster 2    Oth      Станислав Ш.           Minsk    DM
# 1              0.0  Cluster 2    Oth      Станислав Ш.           Minsk    DM
# 2              0.0  Cluster 2    Oth      Станислав Ш.           Minsk    DM
# 3              0.0  Cluster 2    Oth      Станислав Ш.           Minsk    DM
# 4             19.4  Cluster 2    Oth      Станислав Ш.           Minsk    RS
# ...            ...        ...    ...               ...             ...   ...
# 106833         0.0  Cluster 0    Oth      Елизавета Г.  Minsk region-2    AB
# 106834         0.0  Cluster 0    Oth      Елизавета Г.  Minsk region-2    AB
# 106835         0.0  Cluster 0    Oth      Елизавета Г.  Minsk region-2    AB
# 106836         0.0  Cluster 0    Oth      Елизавета Г.  Minsk region-2   ACM
# 106837         0.0  Cluster 0    Oth      Елизавета Г.  Minsk region-2   ACM
#
#        sub_brand            sku_name  active_status
# 0         DM 105     DM-DM 105-48949              1
# 1         DM 105     DM-DM 105-97192              1
# 2         DM 130     DM-DM 130-99639              1
# 3         DM 130     DM-DM 130-99640              1
# 4       RS CR 45  RS-RS CR 45-101209              1
# ...          ...                 ...            ...
# 106833  AB 260 N  AB-AB 260 N-194717              1
# 106834  AB 260 N  AB-AB 260 N-194729              1
# 106835    AB 140    AB-AB 140-194858              1
# 106836     ACM 1    ACM-ACM 1-196459              1
# 106837     ACM 1    ACM-ACM 1-196460              1
#
# [106838 rows x 14 columns]

# %%
df_sales_people = pd.pivot_table(df_sr_customers, index = ['sales_people_name'],
                        values = ['sales_quantity', 'sales_byn', 'scraps_quantity', 'scraps_byn'],
                        aggfunc = 'sum')

df_sales_people['%_scraps_byn'] = df_sales_people['scraps_byn'] / df_sales_people['sales_byn']

df_sales_people['%_scraps_quantity'] = df_sales_people['scraps_quantity'] / df_sales_people['sales_quantity']

df_sales_people = df_sales_people.astype({'sales_byn': 'int64', 'scraps_byn' : 'int64'})

df_sales_people = df_sales_people.sort_values('%_scraps_byn', ascending=False)

#df_sales_people

# %%
df_sales_people_1 = df_sales_people[(df_sales_people['%_scraps_byn'] > 0.03) & (df_sales_people['%_scraps_byn'] <= 1)]

#df_sales_people_1

# %%
df_sales_people.style.\
    map(color_, subset=['%_scraps_byn','%_scraps_quantity']).\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by sales people name")
# Out:
# <style type="text/css">
# #T_bae57_row0_col0, #T_bae57_row0_col2, #T_bae57_row1_col0, #T_bae57_row1_col2, #T_bae57_row2_col0, #T_bae57_row2_col2, #T_bae57_row3_col0, #T_bae57_row3_col2, #T_bae57_row4_col0, #T_bae57_row4_col2, #T_bae57_row5_col0, #T_bae57_row5_col2, #T_bae57_row6_col0, #T_bae57_row6_col2, #T_bae57_row7_col0, #T_bae57_row7_col2, #T_bae57_row8_col0, #T_bae57_row8_col2, #T_bae57_row9_col0, #T_bae57_row9_col2, #T_bae57_row10_col0, #T_bae57_row10_col2, #T_bae57_row11_col0, #T_bae57_row11_col2, #T_bae57_row12_col0, #T_bae57_row12_col2, #T_bae57_row13_col0, #T_bae57_row13_col2, #T_bae57_row14_col0, #T_bae57_row14_col2, #T_bae57_row15_col0, #T_bae57_row15_col2, #T_bae57_row16_col0, #T_bae57_row16_col2, #T_bae57_row17_col0, #T_bae57_row17_col2, #T_bae57_row18_col0, #T_bae57_row18_col2, #T_bae57_row19_col0, #T_bae57_row19_col2, #T_bae57_row20_col0, #T_bae57_row20_col2, #T_bae57_row21_col0, #T_bae57_row21_col2, #T_bae57_row22_col0, #T_bae57_row22_col2, #T_bae57_row23_col0, #T_bae57_row23_col2, #T_bae57_row24_col0, #T_bae57_row24_col2, #T_bae57_row25_col0, #T_bae57_row25_col2, #T_bae57_row26_col0, #T_bae57_row26_col2, #T_bae57_row27_col0, #T_bae57_row27_col2, #T_bae57_row28_col0, #T_bae57_row28_col2, #T_bae57_row29_col0, #T_bae57_row29_col2, #T_bae57_row30_col0, #T_bae57_row30_col2, #T_bae57_row31_col0, #T_bae57_row31_col2, #T_bae57_row32_col0, #T_bae57_row32_col2, #T_bae57_row33_col0, #T_bae57_row33_col2, #T_bae57_row34_col0, #T_bae57_row34_col2, #T_bae57_row35_col0, #T_bae57_row35_col2, #T_bae57_row36_col0, #T_bae57_row36_col2, #T_bae57_row37_col0, #T_bae57_row37_col2, #T_bae57_row38_col0, #T_bae57_row38_col2, #T_bae57_row39_col0, #T_bae57_row39_col2, #T_bae57_row40_col0, #T_bae57_row40_col2, #T_bae57_row41_col0, #T_bae57_row41_col2, #T_bae57_row42_col0, #T_bae57_row42_col2, #T_bae57_row43_col0, #T_bae57_row43_col2, #T_bae57_row44_col0, #T_bae57_row44_col2, #T_bae57_row45_col0, #T_bae57_row45_col2, #T_bae57_row46_col0, #T_bae57_row46_col2, #T_bae57_row47_col0, #T_bae57_row47_col2, #T_bae57_row48_col0, #T_bae57_row48_col2, #T_bae57_row49_col0, #T_bae57_row49_col2, #T_bae57_row50_col0, #T_bae57_row50_col2, #T_bae57_row51_col0, #T_bae57_row51_col2, #T_bae57_row52_col0, #T_bae57_row52_col2, #T_bae57_row53_col0, #T_bae57_row53_col2, #T_bae57_row54_col0, #T_bae57_row54_col2, #T_bae57_row55_col0, #T_bae57_row55_col2, #T_bae57_row56_col0, #T_bae57_row56_col2, #T_bae57_row57_col0, #T_bae57_row57_col2, #T_bae57_row58_col0, #T_bae57_row58_col2, #T_bae57_row59_col0, #T_bae57_row59_col2, #T_bae57_row60_col0, #T_bae57_row60_col2, #T_bae57_row61_col0, #T_bae57_row61_col2, #T_bae57_row62_col0, #T_bae57_row62_col2, #T_bae57_row63_col0, #T_bae57_row63_col2, #T_bae57_row64_col0, #T_bae57_row64_col2, #T_bae57_row65_col0, #T_bae57_row65_col2, #T_bae57_row66_col0, #T_bae57_row66_col2, #T_bae57_row67_col0, #T_bae57_row67_col2, #T_bae57_row68_col0, #T_bae57_row68_col2, #T_bae57_row69_col0, #T_bae57_row69_col2, #T_bae57_row70_col0, #T_bae57_row70_col2, #T_bae57_row71_col0, #T_bae57_row71_col2, #T_bae57_row72_col0, #T_bae57_row72_col2, #T_bae57_row73_col0, #T_bae57_row73_col2, #T_bae57_row74_col0, #T_bae57_row74_col2, #T_bae57_row75_col0, #T_bae57_row75_col2, #T_bae57_row76_col0, #T_bae57_row76_col2, #T_bae57_row77_col0, #T_bae57_row77_col2, #T_bae57_row78_col0, #T_bae57_row78_col2, #T_bae57_row79_col0, #T_bae57_row79_col2, #T_bae57_row80_col0, #T_bae57_row80_col2, #T_bae57_row81_col0, #T_bae57_row81_col2, #T_bae57_row82_col0, #T_bae57_row82_col2, #T_bae57_row83_col0, #T_bae57_row83_col2, #T_bae57_row84_col0, #T_bae57_row84_col2, #T_bae57_row85_col0, #T_bae57_row85_col2, #T_bae57_row86_col0, #T_bae57_row86_col2, #T_bae57_row87_col0, #T_bae57_row87_col2, #T_bae57_row88_col0, #T_bae57_row88_col2, #T_bae57_row89_col0, #T_bae57_row89_col2, #T_bae57_row90_col0, #T_bae57_row90_col2, #T_bae57_row91_col0, #T_bae57_row91_col2, #T_bae57_row92_col0, #T_bae57_row92_col2, #T_bae57_row93_col0, #T_bae57_row93_col2, #T_bae57_row94_col0, #T_bae57_row94_col2, #T_bae57_row95_col0, #T_bae57_ ...
#   width: 150px;
# }
# #T_bae57_row0_col4, #T_bae57_row1_col4, #T_bae57_row2_col4, #T_bae57_row3_col4, #T_bae57_row4_col4, #T_bae57_row5_col4, #T_bae57_row6_col4, #T_bae57_row7_col4, #T_bae57_row8_col4, #T_bae57_row9_col4, #T_bae57_row10_col4, #T_bae57_row11_col4, #T_bae57_row12_col4, #T_bae57_row13_col4, #T_bae57_row14_col4, #T_bae57_row15_col4, #T_bae57_row16_col4, #T_bae57_row17_col4 {
#   color: red;
#   width: 150px;
# }
# #T_bae57_row0_col5, #T_bae57_row1_col5, #T_bae57_row2_col5, #T_bae57_row3_col5, #T_bae57_row4_col5, #T_bae57_row5_col5, #T_bae57_row6_col5, #T_bae57_row8_col5, #T_bae57_row9_col5, #T_bae57_row83_col5 {
#   color: red;
# }
# #T_bae57_row7_col5, #T_bae57_row10_col5, #T_bae57_row11_col5, #T_bae57_row12_col5, #T_bae57_row13_col5, #T_bae57_row14_col5, #T_bae57_row15_col5, #T_bae57_row16_col5, #T_bae57_row17_col5, #T_bae57_row18_col5, #T_bae57_row19_col5, #T_bae57_row20_col5, #T_bae57_row21_col5, #T_bae57_row22_col5, #T_bae57_row23_col5, #T_bae57_row24_col5, #T_bae57_row25_col5, #T_bae57_row26_col5, #T_bae57_row27_col5, #T_bae57_row28_col5, #T_bae57_row29_col5, #T_bae57_row30_col5, #T_bae57_row31_col5, #T_bae57_row32_col5, #T_bae57_row33_col5, #T_bae57_row34_col5, #T_bae57_row35_col5, #T_bae57_row36_col5, #T_bae57_row37_col5, #T_bae57_row38_col5, #T_bae57_row39_col5, #T_bae57_row40_col5, #T_bae57_row41_col5, #T_bae57_row42_col5, #T_bae57_row43_col5, #T_bae57_row44_col5, #T_bae57_row45_col5, #T_bae57_row46_col5, #T_bae57_row47_col5, #T_bae57_row48_col5, #T_bae57_row49_col5, #T_bae57_row50_col5, #T_bae57_row51_col5, #T_bae57_row52_col5, #T_bae57_row53_col5, #T_bae57_row54_col5, #T_bae57_row55_col5, #T_bae57_row56_col5, #T_bae57_row57_col5, #T_bae57_row58_col5, #T_bae57_row59_col5, #T_bae57_row60_col5, #T_bae57_row61_col5, #T_bae57_row62_col5, #T_bae57_row63_col5, #T_bae57_row64_col5, #T_bae57_row65_col5, #T_bae57_row66_col5, #T_bae57_row67_col5, #T_bae57_row68_col5, #T_bae57_row69_col5, #T_bae57_row70_col5, #T_bae57_row71_col5, #T_bae57_row72_col5, #T_bae57_row73_col5, #T_bae57_row74_col5, #T_bae57_row75_col5, #T_bae57_row76_col5, #T_bae57_row77_col5, #T_bae57_row78_col5, #T_bae57_row79_col5, #T_bae57_row80_col5, #T_bae57_row81_col5, #T_bae57_row82_col5, #T_bae57_row84_col5, #T_bae57_row85_col5, #T_bae57_row86_col5, #T_bae57_row87_col5, #T_bae57_row88_col5, #T_bae57_row89_col5, #T_bae57_row90_col5, #T_bae57_row91_col5, #T_bae57_row92_col5, #T_bae57_row93_col5, #T_bae57_row94_col5, #T_bae57_row95_col5, #T_bae57_row96_col5, #T_bae57_row97_col5, #T_bae57_row98_col5, #T_bae57_row99_col5, #T_bae57_row100_col5, #T_bae57_row101_col5 {
#   color: black;
# }
# #T_bae57_row18_col4, #T_bae57_row19_col4, #T_bae57_row20_col4, #T_bae57_row21_col4, #T_bae57_row22_col4, #T_bae57_row23_col4, #T_bae57_row24_col4, #T_bae57_row25_col4, #T_bae57_row26_col4, #T_bae57_row27_col4, #T_bae57_row28_col4, #T_bae57_row29_col4, #T_bae57_row30_col4, #T_bae57_row31_col4, #T_bae57_row32_col4, #T_bae57_row33_col4, #T_bae57_row34_col4, #T_bae57_row35_col4, #T_bae57_row36_col4, #T_bae57_row37_col4, #T_bae57_row38_col4, #T_bae57_row39_col4, #T_bae57_row40_col4, #T_bae57_row41_col4, #T_bae57_row42_col4, #T_bae57_row43_col4, #T_bae57_row44_col4, #T_bae57_row45_col4, #T_bae57_row46_col4, #T_bae57_row47_col4, #T_bae57_row48_col4, #T_bae57_row49_col4, #T_bae57_row50_col4, #T_bae57_row51_col4, #T_bae57_row52_col4, #T_bae57_row53_col4, #T_bae57_row54_col4, #T_bae57_row55_col4, #T_bae57_row56_col4, #T_bae57_row57_col4, #T_bae57_row58_col4, #T_bae57_row59_col4, #T_bae57_row60_col4, #T_bae57_row61_col4, #T_bae57_row62_col4, #T_bae57_row63_col4, #T_bae57_row64_col4, #T_bae57_row65_col4, #T_bae57_row66_col4, #T_bae57_row67_col4, #T_bae57_row68_col4, #T_bae57_row69_col4, #T_bae57_row70_col4, #T_ba

# %%
df_sales_people_1.style.\
    map(color_, subset=['%_scraps_byn','%_scraps_quantity']).\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by sales people name more 3%")
# Out:
# <style type="text/css">
# #T_7073b_row0_col0, #T_7073b_row0_col2, #T_7073b_row1_col0, #T_7073b_row1_col2, #T_7073b_row2_col0, #T_7073b_row2_col2, #T_7073b_row3_col0, #T_7073b_row3_col2, #T_7073b_row4_col0, #T_7073b_row4_col2, #T_7073b_row5_col0, #T_7073b_row5_col2, #T_7073b_row6_col0, #T_7073b_row6_col2, #T_7073b_row7_col0, #T_7073b_row7_col2, #T_7073b_row8_col0, #T_7073b_row8_col2, #T_7073b_row9_col0, #T_7073b_row9_col2, #T_7073b_row10_col0, #T_7073b_row10_col2, #T_7073b_row11_col0, #T_7073b_row11_col2, #T_7073b_row12_col0, #T_7073b_row12_col2, #T_7073b_row13_col0, #T_7073b_row13_col2, #T_7073b_row14_col0, #T_7073b_row14_col2, #T_7073b_row15_col0, #T_7073b_row15_col2, #T_7073b_row16_col0, #T_7073b_row16_col2, #T_7073b_row17_col0, #T_7073b_row17_col2 {
#   width: 150px;
# }
# #T_7073b_row0_col4, #T_7073b_row1_col4, #T_7073b_row2_col4, #T_7073b_row3_col4, #T_7073b_row4_col4, #T_7073b_row5_col4, #T_7073b_row6_col4, #T_7073b_row7_col4, #T_7073b_row8_col4, #T_7073b_row9_col4, #T_7073b_row10_col4, #T_7073b_row11_col4, #T_7073b_row12_col4, #T_7073b_row13_col4, #T_7073b_row14_col4, #T_7073b_row15_col4, #T_7073b_row16_col4, #T_7073b_row17_col4 {
#   color: red;
#   width: 150px;
# }
# #T_7073b_row0_col5, #T_7073b_row1_col5, #T_7073b_row2_col5, #T_7073b_row3_col5, #T_7073b_row4_col5, #T_7073b_row5_col5, #T_7073b_row6_col5, #T_7073b_row8_col5, #T_7073b_row9_col5 {
#   color: red;
# }
# #T_7073b_row7_col5, #T_7073b_row10_col5, #T_7073b_row11_col5, #T_7073b_row12_col5, #T_7073b_row13_col5, #T_7073b_row14_col5, #T_7073b_row15_col5, #T_7073b_row16_col5, #T_7073b_row17_col5 {
#   color: black;
# }
# </style>
# <table id="T_7073b">
#   <caption>Scraps and losses in October 2023 by sales people name more 3%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7073b_level0_col0" class="col_heading level0 col0" >sales_byn</th>
#       <th id="T_7073b_level0_col1" class="col_heading level0 col1" >sales_quantity</th>
#       <th id="T_7073b_level0_col2" class="col_heading level0 col2" >scraps_byn</th>
#       <th id="T_7073b_level0_col3" class="col_heading level0 col3" >scraps_quantity</th>
#       <th id="T_7073b_level0_col4" class="col_heading level0 col4" >%_scraps_byn</th>
#       <th id="T_7073b_level0_col5" class="col_heading level0 col5" >%_scraps_quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sales_people_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7073b_level0_row0" class="row_heading level0 row0" >Татьяна Д.</th>
#       <td id="T_7073b_row0_col0" class="data row0 col0" >542 966</td>
#       <td id="T_7073b_row0_col1" class="data row0 col1" >424 910</td>
#       <td id="T_7073b_row0_col2" class="data row0 col2" >50 446</td>
#       <td id="T_7073b_row0_col3" class="data row0 col3" >32 230</td>
#       <td id="T_7073b_row0_col4" class="data row0 col4" >9,3%</td>
#       <td id="T_7073b_row0_col5" class="data row0 col5" >7,6%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row1" class="row_heading level0 row1" >Анастасия Ф.</th>
#       <td id="T_7073b_row1_col0" class="data row1 col0" >274 919</td>
#       <td id="T_7073b_row1_col1" class="data row1 col1" >208 360</td>
#       <td id="T_7073b_row1_col2" class="data row1 col2" >15 941</td>
#       <td id="T_7073b_row1_col3" class="data row1 col3" >12 970</td>
#       <td id="T_7073b_row1_col4" class="data row1 col4" >5,8%</td>
#       <td id="T_7073b_row1_col5" class="data row1 col5" >6,2%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row2" class="row_heading level0 row2" >Наталья Л.</th>
#       <td id="T_7073b_row2_col0" class="data row2 col0" >644 426</td>
#       <td id="T_7073b_row2_col1" class="data row2 col1" >530 830</td>
#       <td id="T_7073b_row2_col2" class="data row2 col2" >27 378</td>
#       <td id="T_7073b_row2_col3" class="data row2 col3" >19 680</td>
#       <td id="T_7073b_row2_col4" class="data row2 col4" >4,2%</td>
#       <td id="T_7073b_row2_col5" class="data row2 col5" >3,7%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row3" class="row_heading level0 row3" >Наталья Г.</th>
#       <td id="T_7073b_row3_col0" class="data row3 col0" >716 084</td>
#       <td id="T_7073b_row3_col1" class="data row3 col1" >597 530</td>
#       <td id="T_7073b_row3_col2" class="data row3 col2" >27 733</td>
#       <td id="T_7073b_row3_col3" class="data row3 col3" >19 250</td>
#       <td id="T_7073b_row3_col4" class="data row3 col4" >3,9%</td>
#       <td id="T_7073b_row3_col5" class="data row3 col5" >3,2%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row4" class="row_heading level0 row4" >Юлия М.</th>
#       <td id="T_7073b_row4_col0" class="data row4 col0" >673 657</td>
#       <td id="T_7073b_row4_col1" class="data row4 col1" >559 220</td>
#       <td id="T_7073b_row4_col2" class="data row4 col2" >26 007</td>
#       <td id="T_7073b_row4_col3" class="data row4 col3" >19 280</td>
#       <td id="T_7073b_row4_col4" class="data row4 col4" >3,9%</td>
#       <td id="T_7073b_row4_col5" class="data row4 col5" >3,4%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row5" class="row_heading level0 row5" >Татьяна К.</th>
#       <td id="T_7073b_row5_col0" class="data row5 col0" >815 454</td>
#       <td id="T_7073b_row5_col1" class="data row5 col1" >659 410</td>
#       <td id="T_7073b_row5_col2" class="data row5 col2" >29 007</td>
#       <td id="T_7073b_row5_col3" class="data row5 col3" >20 880</td>
#       <td id="T_7073b_row5_col4" class="data row5 col4" >3,6%</td>
#       <td id="T_7073b_row5_col5" class="data row5 col5" >3,2%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row6" class="row_heading level0 row6" >Лилия К.</th>
#       <td id="T_7073b_row6_col0" class="data row6 col0" >300 601</td>
#       <td id="T_7073b_row6_col1" class="data row6 col1" >231 050</td>
#       <td id="T_7073b_row6_col2" class="data row6 col2" >10 641</td>
#       <td id="T_7073b_row6_col3" class="data row6 col3" >8 420</td>
#       <td id="T_7073b_row6_col4" class="data row6 col4" >3,5%</td>
#       <td id="T_7073b_row6_col5" class="data row6 col5" >3,6%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row7" class="row_heading level0 row7" >Павел Т.</th>
#       <td id="T_7073b_row7_col0" class="data row7 col0" >673 632</td>
#       <td id="T_7073b_row7_col1" class="data row7 col1" >562 080</td>
#       <td id="T_7073b_row7_col2" class="data row7 col2" >23 636</td>
#       <td id="T_7073b_row7_col3" class="data row7 col3" >16 340</td>
#       <td id="T_7073b_row7_col4" class="data row7 col4" >3,5%</td>
#       <td id="T_7073b_row7_col5" class="data row7 col5" >2,9%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row8" class="row_heading level0 row8" >Марина Ж.</th>
#       <td id="T_7073b_row8_col0" class="data row8 col0" >451 060</td>
#       <td id="T_7073b_row8_col1" class="data row8 col1" >362 310</td>
#       <td id="T_7073b_row8_col2" class="data row8 col2" >15 800</td>
#       <td id="T_7073b_row8_col3" class="data row8 col3" >11 470</td>
#       <td id="T_7073b_row8_col4" class="data row8 col4" >3,5%</td>
#       <td id="T_7073b_row8_col5" class="data row8 col5" >3,2%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row9" class="row_heading level0 row9" >Светлана М.</th>
#       <td id="T_7073b_row9_col0" class="data row9 col0" >644 372</td>
#       <td id="T_7073b_row9_col1" class="data row9 col1" >504 540</td>
#       <td id="T_7073b_row9_col2" class="data row9 col2" >22 444</td>
#       <td id="T_7073b_row9_col3" class="data row9 col3" >16 860</td>
#       <td id="T_7073b_row9_col4" class="data row9 col4" >3,5%</td>
#       <td id="T_7073b_row9_col5" class="data row9 col5" >3,3%</td>
#     </tr>
#     <tr>
#       <th id="T_7073b_level0_row10" class="row_heading level0 row10" >Ольга Л.</th>
#       <td id="T_7073b_row10_col0" class="data row10 col0" >464 109</td>
#       <td id="T_7073b_row10_col1" class="data r

# %% [markdown]
# Такие высокие уровни возвратов требуют детального изучения по каждому сотруднику.

# %%
df_sales_people_sku_111 = pd.pivot_table(df_sales_people_sku, index = ['sales_people_name', 'sub_brand'],
                        values = ['sales_quantity', 'sales_byn', 'scraps_quantity', 'scraps_byn'],
                        aggfunc = 'sum')

df_sales_people_sku_111['%_scraps_byn'] = df_sales_people_sku_111['scraps_byn'] / df_sales_people_sku_111['sales_byn']

df_sales_people_sku_111['%_scraps_quantity'] = df_sales_people_sku_111['scraps_quantity'] / df_sales_people_sku_111['sales_quantity']

df_sales_people_sku_111 = df_sales_people_sku_111.astype({'sales_byn': 'int64', 'scraps_byn' : 'int64'})

df_sales_people_sku_111 = df_sales_people_sku_111.sort_values('%_scraps_byn', ascending=False)

(df_sales_people_sku_111.loc['Татьяна Д.', :]).sort_values('%_scraps_byn', ascending=False).style.\
    map(color_, subset=['%_scraps_byn','%_scraps_quantity']).\
    format({'%_scraps_byn' : "{:.1%}", '%_scraps_quantity' : "{:.1%}"}, thousands=' ', decimal=',').\
    set_properties(subset=['sales_byn', 'scraps_byn', '%_scraps_byn'], **{'width': '150px'}).\
    set_caption(f"Scraps and losses in {period} by sales people name (Татьяна Д.)")
# Out:
# <style type="text/css">
# #T_68d37_row0_col0, #T_68d37_row0_col2, #T_68d37_row1_col0, #T_68d37_row1_col2, #T_68d37_row2_col0, #T_68d37_row2_col2, #T_68d37_row3_col0, #T_68d37_row3_col2, #T_68d37_row4_col0, #T_68d37_row4_col2, #T_68d37_row5_col0, #T_68d37_row5_col2, #T_68d37_row6_col0, #T_68d37_row6_col2, #T_68d37_row7_col0, #T_68d37_row7_col2, #T_68d37_row8_col0, #T_68d37_row8_col2, #T_68d37_row9_col0, #T_68d37_row9_col2, #T_68d37_row10_col0, #T_68d37_row10_col2, #T_68d37_row11_col0, #T_68d37_row11_col2, #T_68d37_row12_col0, #T_68d37_row12_col2, #T_68d37_row13_col0, #T_68d37_row13_col2, #T_68d37_row14_col0, #T_68d37_row14_col2, #T_68d37_row15_col0, #T_68d37_row15_col2, #T_68d37_row16_col0, #T_68d37_row16_col2, #T_68d37_row17_col0, #T_68d37_row17_col2, #T_68d37_row18_col0, #T_68d37_row18_col2, #T_68d37_row19_col0, #T_68d37_row19_col2, #T_68d37_row20_col0, #T_68d37_row20_col2, #T_68d37_row21_col0, #T_68d37_row21_col2, #T_68d37_row22_col0, #T_68d37_row22_col2, #T_68d37_row23_col0, #T_68d37_row23_col2, #T_68d37_row24_col0, #T_68d37_row24_col2, #T_68d37_row25_col0, #T_68d37_row25_col2, #T_68d37_row26_col0, #T_68d37_row26_col2, #T_68d37_row27_col0, #T_68d37_row27_col2, #T_68d37_row28_col0, #T_68d37_row28_col2, #T_68d37_row29_col0, #T_68d37_row29_col2, #T_68d37_row30_col0, #T_68d37_row30_col2, #T_68d37_row31_col0, #T_68d37_row31_col2, #T_68d37_row32_col0, #T_68d37_row32_col2, #T_68d37_row33_col0, #T_68d37_row33_col2, #T_68d37_row34_col0, #T_68d37_row34_col2, #T_68d37_row35_col0, #T_68d37_row35_col2, #T_68d37_row36_col0, #T_68d37_row36_col2, #T_68d37_row37_col0, #T_68d37_row37_col2 {
#   width: 150px;
# }
# #T_68d37_row0_col4, #T_68d37_row1_col4, #T_68d37_row2_col4, #T_68d37_row3_col4, #T_68d37_row4_col4, #T_68d37_row5_col4, #T_68d37_row6_col4, #T_68d37_row37_col4 {
#   color: grey;
#   width: 150px;
# }
# #T_68d37_row0_col5, #T_68d37_row1_col5, #T_68d37_row2_col5, #T_68d37_row3_col5, #T_68d37_row4_col5, #T_68d37_row5_col5, #T_68d37_row6_col5, #T_68d37_row37_col5 {
#   color: grey;
# }
# #T_68d37_row7_col4, #T_68d37_row8_col4, #T_68d37_row9_col4, #T_68d37_row10_col4, #T_68d37_row11_col4, #T_68d37_row12_col4, #T_68d37_row13_col4, #T_68d37_row14_col4, #T_68d37_row15_col4, #T_68d37_row16_col4, #T_68d37_row17_col4, #T_68d37_row18_col4, #T_68d37_row19_col4, #T_68d37_row20_col4, #T_68d37_row21_col4, #T_68d37_row22_col4, #T_68d37_row23_col4, #T_68d37_row24_col4, #T_68d37_row25_col4 {
#   color: red;
#   width: 150px;
# }
# #T_68d37_row7_col5, #T_68d37_row8_col5, #T_68d37_row9_col5, #T_68d37_row10_col5, #T_68d37_row11_col5, #T_68d37_row12_col5, #T_68d37_row13_col5, #T_68d37_row14_col5, #T_68d37_row15_col5, #T_68d37_row16_col5, #T_68d37_row17_col5, #T_68d37_row18_col5, #T_68d37_row19_col5, #T_68d37_row20_col5, #T_68d37_row21_col5, #T_68d37_row22_col5, #T_68d37_row23_col5, #T_68d37_row24_col5, #T_68d37_row25_col5 {
#   color: red;
# }
# #T_68d37_row26_col4, #T_68d37_row27_col4, #T_68d37_row28_col4, #T_68d37_row29_col4, #T_68d37_row30_col4, #T_68d37_row31_col4, #T_68d37_row32_col4, #T_68d37_row33_col4, #T_68d37_row34_col4, #T_68d37_row35_col4, #T_68d37_row36_col4 {
#   color: black;
#   width: 150px;
# }
# #T_68d37_row26_col5, #T_68d37_row27_col5, #T_68d37_row28_col5, #T_68d37_row29_col5, #T_68d37_row30_col5, #T_68d37_row31_col5, #T_68d37_row32_col5, #T_68d37_row33_col5, #T_68d37_row34_col5, #T_68d37_row35_col5, #T_68d37_row36_col5 {
#   color: black;
# }
# </style>
# <table id="T_68d37">
#   <caption>Scraps and losses in October 2023 by sales people name (Татьяна Д.)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68d37_level0_col0" class="col_heading level0 col0" >sales_byn</th>
#       <th id="T_68d37_level0_col1" class="col_heading level0 col1" >sales_quantity</th>
#       <th id="T_68d37_level0_col2" class="col_heading level0 col2" >scraps_byn</th>
#       <th id="T_68d37_level0_col3" class="col_heading level0 col3" >scraps_quantity</th>
#       <th id="T_68d37_level0_col4" class="col_heading level0 col4" >%_scraps_byn</th>
#       <th id="T_68d37_level0_col5" class="col_heading level0 col5" >%_scraps_quantity</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sub_brand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68d37_level0_row0" class="row_heading level0 row0" >AV SP 140</th>
#       <td id="T_68d37_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_68d37_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_68d37_row0_col2" class="data row0 col2" >114</td>
#       <td id="T_68d37_row0_col3" class="data row0 col3" >110</td>
#       <td id="T_68d37_row0_col4" class="data row0 col4" >inf%</td>
#       <td id="T_68d37_row0_col5" class="data row0 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row1" class="row_heading level0 row1" >AM 1 95</th>
#       <td id="T_68d37_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_68d37_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_68d37_row1_col2" class="data row1 col2" >3 565</td>
#       <td id="T_68d37_row1_col3" class="data row1 col3" >3 360</td>
#       <td id="T_68d37_row1_col4" class="data row1 col4" >inf%</td>
#       <td id="T_68d37_row1_col5" class="data row1 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row2" class="row_heading level0 row2" >AV DR 260</th>
#       <td id="T_68d37_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_68d37_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_68d37_row2_col2" class="data row2 col2" >761</td>
#       <td id="T_68d37_row2_col3" class="data row2 col3" >550</td>
#       <td id="T_68d37_row2_col4" class="data row2 col4" >inf%</td>
#       <td id="T_68d37_row2_col5" class="data row2 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row3" class="row_heading level0 row3" >AV DR 260 NS</th>
#       <td id="T_68d37_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_68d37_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_68d37_row3_col2" class="data row3 col2" >544</td>
#       <td id="T_68d37_row3_col3" class="data row3 col3" >320</td>
#       <td id="T_68d37_row3_col4" class="data row3 col4" >inf%</td>
#       <td id="T_68d37_row3_col5" class="data row3 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row4" class="row_heading level0 row4" >AV SP 110</th>
#       <td id="T_68d37_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_68d37_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_68d37_row4_col2" class="data row4 col2" >49</td>
#       <td id="T_68d37_row4_col3" class="data row4 col3" >70</td>
#       <td id="T_68d37_row4_col4" class="data row4 col4" >inf%</td>
#       <td id="T_68d37_row4_col5" class="data row4 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row5" class="row_heading level0 row5" >AV SP 130</th>
#       <td id="T_68d37_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_68d37_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_68d37_row5_col2" class="data row5 col2" >239</td>
#       <td id="T_68d37_row5_col3" class="data row5 col3" >280</td>
#       <td id="T_68d37_row5_col4" class="data row5 col4" >inf%</td>
#       <td id="T_68d37_row5_col5" class="data row5 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row6" class="row_heading level0 row6" >AV SP 130 NS</th>
#       <td id="T_68d37_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_68d37_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_68d37_row6_col2" class="data row6 col2" >111</td>
#       <td id="T_68d37_row6_col3" class="data row6 col3" >110</td>
#       <td id="T_68d37_row6_col4" class="data row6 col4" >inf%</td>
#       <td id="T_68d37_row6_col5" class="data row6 col5" >inf%</td>
#     </tr>
#     <tr>
#       <th id="T_68d37_level0_row7" class="row_heading level0 row7" >DM 190</th>
#       <td id="T_68d37_row

# %% [markdown]
# Разберем работу конкретного сотрудника.
#
# Несмотря на то, что продукт PR M 900 был недавно выведен из продажи, такой высокий уровень возвратов не может быть обусловлен выводом или непопаданием в прогноз. Возможно, торговый представитель делал заказ наугад.
#
# Высокий уровень возвратов у продукта PR B 160 нельзя объяснить ничем, кроме как ошибки сотрудника: у данного продукта большой срок годности и стабильный уровень спроса. Так как данный продукт является одним из самых дорогих, то, возможно, сотрудник хотел выполнить план по продажам и перезаказал продукт (один из самых дорогих продуктов + плюс большой срок годности, однако продукта оказалось слишком много).

# %% [markdown]
# ### Создание базы данных:
#
# Использование postgres и dbeaver
# Построение модели и установка ограничений
# Загрузка данных

# %% [markdown]
# ### Создание dashboard в Power BI

# %% [markdown]
# <img src='dashboard.png'>
